# %% [markdown]
# 1. Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR

# %% [markdown]
# 2. Import dataset

# %%
# 2. Importing the dataset
df = pd.read_csv('Dataset\Experience-Salary.csv')
X = df.iloc[:, 0].values
y = df.iloc[:, 1].values
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_30384\3697578563.py:2: SyntaxWarning: invalid escape sequence '\E'
#   df = pd.read_csv('Dataset\Experience-Salary.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   exp(in months)        1000 non-null   float64
#  1   salary(in thousands)  1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %% [markdown]
# 3. Standarisasi Fitur

# %%
# 3. Standarisasi Fitur
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X.reshape(-1, 1))

# %% [markdown]
# 4. Membagi data training dan testing

# %%
# 4. Membagi Data menjadi Data Latih dan Data Uji
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# 5. Membuat dan melatih Model

# %%
# 5. Membuat dan Melatih Model SVM
svm_model = SVR(kernel='linear')
svm_model.fit(X_train, y_train)
# Out:
# SVR(kernel='linear')

# %% [markdown]
# 6. Evaluasi Model

# %%
# 6. Evaluasi Model
train_score = svm_model.score(X_train, y_train)
test_score = svm_model.score(X_test, y_test)

print("Training Score:", train_score)
print("Testing Score:", test_score)
# Out:
# Training Score: 0.6656435620537712
# Testing Score: 0.6217776235476473

# %% [markdown]
# 7. Visualisasi Data

# %%
# 7. Visualisasi Data dan Garis Regresi
plt.scatter(X_train, y_train, color='blue', label='Training Data')
plt.scatter(X_test, y_test, color='red', label='Testing Data')
plt.plot(X_scaled, svm_model.predict(X_scaled), color='black', linewidth=2, label='Linear SVR')
plt.xlabel('Experience (scaled)')
plt.ylabel('Salary')
plt.title('SVR Model')
plt.legend()
plt.show()
